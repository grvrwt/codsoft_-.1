# %%
# importing important libraries/dependencies
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
# exploring our given data
titanic_data  = pd.read_csv(r"C:\Users\gaura\OneDrive\Desktop\Internship Codesoft\Datasets\tested.csv")

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic_data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
titanic_data.shape
# Out:
# (418, 12)

# %% [markdown]
# A total of 418 rows and 12 columns

# %%
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# These are all the columns that are present in our data

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#cheking for any null values
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sns.heatmap(titanic_data.isnull() , cmap = 'spring')
# Out:
# <Axes: >

# %%
#dropping the redundancies 
titanic_data.drop(['Cabin','Ticket','Name','PassengerId'],axis =1 , inplace= True)

# %%
#dropping the null values
titanic_data.dropna(inplace=True)

# %%
titanic_data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
titanic_data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 409         1       3  female   3.0      1      1   13.7750        S
# 411         1       1  female  37.0      1      0   90.0000        Q
# 412         1       3  female  28.0      0      0    7.7750        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
#
# [331 rows x 8 columns]

# %% [markdown]
# # Visualization to find any relation between data

# %%
sns.relplot(x='Survived',y = 'Age' , data = titanic_data)

# %%
sns.relplot(x='Survived',y = 'Fare' , data = titanic_data)

# %%
sns.relplot(x='Survived',y = 'Sex' , data = titanic_data)

# %% [markdown]
# So we found a relationship between 'Sex' and 'Survived'. From which we can create our linear regression model.
# The relationship is that the 'female' in the titanic_data have all survived regardlees of their age and all 'male' didn't survive the titanic crash. So we will build the model using this relationship.

# %%
titanic_data.replace({'Sex':{'male':0,'female':1},'Embarked':{'S':0,'C':1,'Q':3}}, inplace =True)

# %%
sns.pairplot(titanic_data , hue = "Survived")

# %%
titanic_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0           0       3    0  34.5      0      0    7.8292         3
# 1           1       3    1  47.0      1      0    7.0000         0
# 2           0       2    0  62.0      0      0    9.6875         3
# 3           0       3    0  27.0      0      0    8.6625         0
# 4           1       3    1  22.0      1      1   12.2875         0
# ..        ...     ...  ...   ...    ...    ...       ...       ...
# 409         1       3    1   3.0      1      1   13.7750         0
# 411         1       1    1  37.0      1      0   90.0000         3
# 412         1       3    1  28.0      0      0    7.7750         0
# 414         1       1    1  39.0      0      0  108.9000         1
# 415         0       3    0  38.5      0      0    7.2500         0
#
# [331 rows x 8 columns]

# %% [markdown]
# # Creating the model

# %%
pd.set_option('display.max.rows', 416)

# %% [markdown]
# Training the data

# %%
from sklearn.model_selection import train_test_split

# %%
train = titanic_data.drop(['Survived'], axis = 1)
test = titanic_data['Survived']

# %%
X_train , X_test, y_train , y_test = train_test_split(train , test , test_size = 0.2 , random_state = 4)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lm = LogisticRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction = lm.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test , prediction)
# Out:
# array([[38,  0],
#        [ 0, 29]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prediction)
# Out:
# 1.0
